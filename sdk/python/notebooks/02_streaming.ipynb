# %% [markdown]
# # Streaming
# Show token-like deltas using `stream_text`.

# %%
from codex_app_server import AppServerClient

with AppServerClient() as client:
    client.initialize()
    conv = client.conversation_start()
    for chunk in conv.stream_text("Write a haiku about compilers"):
        print(chunk, end="")
    print()
