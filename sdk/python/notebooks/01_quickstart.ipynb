# %% [markdown]
# # Quickstart
# Minimal sync flow with fluent conversation helpers.

# %%
from codex_app_server import AppServerClient

with AppServerClient() as client:
    client.initialize()
    conv = client.conversation_start(model="gpt-5")
    result = conv.ask_result("Give me 3 bullet points about SIMD")
    print(result.text)
